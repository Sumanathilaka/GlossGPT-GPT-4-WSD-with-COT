# %% [markdown]
# # This phase Try to evaluate the WSD as iterative Binary Classification.

# %% [markdown]
# - Steps to follow
#
# 1. Identify the senses/glosses based on the POS tag
# 2. Iterative idenitify the sense/gloss based on the approach

# %%
import os, yaml, re
from openai import OpenAI, ChatCompletion

# %%
with open('cadentials.yaml') as f:
    cadentials = yaml.load(f, Loader=yaml.FullLoader)

os.environ['OPENAI_API_KEY'] = cadentials['OPENAI_API_KEY']

# %%
client = OpenAI()

# %%
def complete_model(USER_MESSAGE):
    response = client.chat.completions.create(
                                            model = 'gpt-3.5-turbo',
                                            messages = [
                                                        {"role": "system", "content" : "You are a helpful assitant to identify the tag for sense of a word"},
                                                        {"role": "user", "content": USER_MESSAGE}              
                                                        ],
                                            temperature=0,
                                            max_tokens=1500
                                            )
    return str(response.choices[0].message.content)

# %%
# Read data from file
with open('senses.txt', 'r',encoding="utf8") as file:
    data = file.read()

# Split the data into entries based on empty lines
entries = data.strip().split('\n\n')
print("No of sense tags in FEWS dataset ",len(entries))

# Create a list of lists for each entry's details
list_of_lists = []
for entry in entries:
    details = entry.split('\n')
    entry_list = []
    for detail in details:
        _, value = detail.split(':', 1)
        entry_list.append(value.strip())
    list_of_lists.append(entry_list)

# Print the instance from the sense tag
print(list_of_lists[0])
# Out:
# No of sense tags in FEWS dataset  663730
# ['dictionary.noun.0', 'dictionary', "A reference work with a list of words from one or more languages, normally ordered alphabetically, explaining each word's meaning, and sometimes containing information on its etymology, pronunciation, usage, translations, and other data.", '', '1', 'wordbook']

# %%
#converting the word into the base word as the sense are kept in base
def word_base(word):
    try:
        word=stemmer.stem(word)
        base_word = lemmatizer.lemmatize(word)
        return base_word
    except:
        return word

# %%
#function to retrieve the word meaning from the list_of_list list
#this function will specifically read the sense id and the meaning(gloss) which is required for the processing.
def retrieve_meanings(word, data):
    meanings_dict = {}
    for entry in data:
        if word == entry[0].split(".")[0]:
            if entry[-1] !="":
                meanings_dict[entry[0]] = entry[2]+", synonyms :"+entry[-1]
            else:
                meanings_dict[entry[0]] = entry[2]
    return meanings_dict

# %%
#Extract the sentence without <wsd> token and the index
def extract_word_and_index(sentence):
    # Find the start and end index of the <WSD> tags
    start_index = sentence.find('<WSD>')    
    end_index = sentence.find('</WSD>')
    

    if start_index != -1 and end_index != -1:
        # Extract the word between <WSD> tags
        word = sentence[start_index + len('<WSD>'):end_index]

        # Remove <WSD> and </WSD> tags from the sentence
        cleaned_sentence = sentence[:start_index] + word+" " + sentence[end_index + len('</WSD>'):]
            
        return cleaned_sentence.strip()

# %%
#Function to identify the WSD word from the given sentence and return the WSD word on a sentence
def wsdword(text):
    match = re.search(r'<WSD>(.*?)</WSD>', text)
    if match:
        word_inside_wsd = match.group(1)
        return word_inside_wsd

# %%
#Funtion to counts the number of tokens : input and output tokens
from nltk.tokenize import word_tokenize

def count_tokens(text):
    # Tokenize the input text
    tokens = word_tokenize(text)
    
    # Count the tokens in the input
    token_count = len(tokens)
    
    return token_count

# %%
#Word lemmatizer to get the base word of the WSD word
import nltk
from nltk.stem import WordNetLemmatizer, PorterStemmer

nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\2358452\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import json
def load_dictionary_from_file(filename):
    try:
        with open(filename, 'r') as file:
            data_dict = json.load(file)
        return data_dict
    except FileNotFoundError:
        # Handle the case where the file doesn't exist
        return None
    except json.JSONDecodeError:
        # Handle the case where the file contains invalid JSON
        return None

# %%
def postag_preprocess(pos_tag):
    if pos_tag=="adj":
        return "adjective"
    elif pos_tag=="noun" or pos_tag=="verb":
        return pos_tag
    else:
        return None

# %%
loaded_dict = load_dictionary_from_file("my_dictionary.json")

# %%
def sense_Tag_Return_pipeline(sentence,postag,wordwsd):
    
        ob="{"
        cb="}"
        
        meanings = retrieve_meanings(wordwsd, list_of_lists)
        #print(meanings)
        cleaned_sentence= extract_word_and_index(sentence) 
        
        #retrieving the data form the dictionary
        filtered_definitions = {key: value for key, value in meanings.items() if postag in key}
        meaning_list= list(filtered_definitions.items())      
        #print(meaning_list)
        count=0 #variable to count the tokens 
        
        if wsdword(sentence) in loaded_dict:
            #print("examples found")
            examples=loaded_dict[wsdword(sentence)]
            try:
                examples=examples[postag]
            except:
                examples=examples
            

        elif word_base(wsdword(sentence)) in loaded_dict:
            #print("examples found")
            examples=loaded_dict[word_base(wsdword(sentence))]
            try:
                examples=examples[postag]
            except:
                examples=examples
        else:
            examples=None
            
        #print(examples)
        
        output=meaning_list[0]
        count=0 #variable to count the tokens 
        for count_meaning in range(0,len(meaning_list)-1):
            #print("new Iteration")    
            sense_def1=[]
            sense_def2=[]
            
            if(examples != None):
                for example in examples:
                    if output[0] in example:
                        sense_def1.append(example)
                    elif meaning_list[count_meaning+1][0] in example:
                        sense_def2.append(example)

            #print("Sense Examples")  
            #print(sense_def1)
            #print(sense_def2)

                    
            prompt = f'''You are going to identify the most suitable sense tag of an ambiguous word in English sentence.
    1. Below are two possible meanings for word {wordwsd}. Comprehend the sense tags and meanings.
        - 1st meaning {output}
        - 2nd meaning {meaning_list[count_meaning+1]}
    2. You can learn more on the usage of each word and the its sense through the examples below if provided. 
        - 1st meaning Examples : {sense_def1}
        - 2nd meaning Examples : {sense_def2}
    3. Now carefully examine the sentence below. The ambiguous word is enclosed within <WSD>."{sentence}"
    4. Analyze the sentence carefully and identify the meaning of the ambiguous word. Use below techniques
    - Traverse the sentence and identify the important keywords which help to identify the meaning of the ambiguous word. 
    - Then you can think about the contextual meaning of the sentence and decide the most suitable meaning for the ambiguous word.
    5. Based on the identified meaning, try to find the most appropriate senseID from the above two sense ids. Selection of a one sense is mandatory. 
    6. Return only the identified senseid in the below JSON format.
    {ob}"sense_id":  the identified sense id{cb}  ''' 
            
            count+=count_tokens(prompt)
            response=complete_model(prompt)
            #print("Response :")
            #print(response)
            count+=count_tokens(str(output))
            if output[0] in response:
                output=output
            else:
                output=meaning_list[count_meaning+1]

            #print("Output of each iteration:")
            #print(output)


        return output,count

# %%
import datetime
#evaluating the results
filename="missing_data_analysis/binaryclassificationNew"+datetime.date.today().strftime("%B %d, %Y")+".txt"
file=open("missing_data_analysis/missing_test_data_new.txt","r",encoding="utf8")

file2=open(filename,"w",encoding="utf8")
totalTokens=0
for i in file:
    lst=i.split("	")
    sentence,senseid=lst[0],lst[1]
    postag=senseid.split(".")[1]  #postag 
    wordfromtext=senseid.split(".")[0] #wsdword
    #print(postag)
    foutput,token_count=sense_Tag_Return_pipeline(sentence,postag,wordfromtext)
    totalTokens+=token_count
    #print(output)
    print(foutput)
    #writing the output in the file
    file2.write(str(foutput) + "\n")
    

file.close()
file2.close()
print(totalTokens)
# Out:
# ('ergative.noun.1', 'An ergative verb or other expression.')
# ('pubbie.noun.3', 'Someone that one socializes with at the pub.')
# ('interferant.noun.1', 'A compound in the sample that produces readings which overlap those of the analyte, making analysis more difficult.')
# ('bean_flicker.noun.0', 'A lesbian.')
# ('kirtle.verb.0', 'To clothe or cover with, or as if with, a kirtle; to hitch up (a long garment) to the length of a kirtle.')
# ('draw_a_line_in_the_sand.verb.2', 'To indicate the threshold or level above which something will become unacceptable or will provoke a response; to create a boundary and imply or declare that its crossing will provoke a (negative) response.')
# ('lay_a_glove_on.verb.0', 'To hit with a boxing glove.')
# ('dawdle.verb.1', 'To spend (time) without haste or purpose.')
# ('furnish.verb.1', 'To supply or give (something).')
# ('splatch.verb.2', 'To move in a manner that causes splashing or spreading of material.')
# ('desire.verb.1', 'To put a request to (someone); to entreat.')
# ('unmanly.adjective.0', 'Showing characteristics that are not manly, such as being immature, effeminate or cowardly, which might be construed as an indicator of weakness or of baseness of character.')
# ('juvenile.adjective.0', 'Young; not fully developed.')
# ('large-handed.adjective.1', 'Spending or giving in large quantities; generous or spendthrift.')
# 9320

# %%
import datetime
#evaluating the results
filename="missing_data_analysis/binaryclassification"+datetime.date.today().strftime("%B %d, %Y")+".txt"
file=open("missing_data_analysis/missing_test_data.txt","r",encoding="utf8")

file2=open(filename,"w",encoding="utf8")
totalTokens=0
for i in file:
    lst=i.split("	")
    sentence,senseid=lst[0],lst[1]
    postag=senseid.split(".")[1]  #postag 
    wordfromtext=senseid.split(".")[0] #wsdword
    #print(postag)
    foutput,token_count=sense_Tag_Return_pipeline(sentence,postag,wordfromtext)
    totalTokens+=token_count
    #print(output)
    print(foutput)
    #writing the output in the file
    file2.write(str(foutput) + "\n")
    

file.close()
file2.close()
print(totalTokens)
# Out:
# ('corbeau.noun.2', 'A very dark shade of green, almost black.')
# ('beast.noun.0', 'Any animal other than a human; usually only applied to land vertebrates, especially large or dangerous four-footed ones.')
# ('brake.noun.1', 'A thicket, or an area overgrown with briers etc. (from 15th c.)')
# ('godship.noun.1', '(nodot=a): the state, position, or fact of being a god.')
# ('eyeballer.noun.4', 'Someone who stares at another in order to intimidate them.')
# ('stage.noun.1', 'A platform; a surface, generally elevated, upon which show performances or other public events are given.')
# ('part.noun.0', 'A portion; a component.')
# ('lord.noun.3', 'One possessing similar mastery over others;  any feudal superior generally; any nobleman or aristocrat; any chief, prince, or sovereign ruler; in Scotland, a male member of the lowest rank of nobility (the equivalent rank in England is "baron")')
# ('red_shirt.noun.8', 'A member of the UDD.')
# ('glamourama.noun.1', 'An event or setting noted for its glamour or celebrity status')
# ('entropology.noun.0', 'The study of human actions that lead to the disintegration and increasing disorder of highly evolved social systems.')
# ('corruption.noun.0', 'The act of corrupting or of impairing integrity, virtue, or moral principle; the state of being corrupted or debased; loss of purity or integrity; depravity; wickedness; impurity; bribery.')
# ('magic.noun.3', 'Something producing successful and remarkable results, especially when not fully understood; an enchanting quality; exceptional skill. (from 17th c.)')
# ('concretization.noun.1', 'Something specific which is the result of a process of concretizing a general principle or idea.')
# ('bourne.noun.1', 'A goal or destination.')
# ('egg_crating.noun.2', '(egg-crating) (plastic mat)')
# ('concept.noun.0', 'abstract and general idea; an abstraction')
# ('farming.noun.1', 'A farming operation; a farm, or instance of farming on a piece of land.')
# ('naturalism.noun.4', 'A movement in theatre, film, and literature that seeks to replicate a believable everyday reality, as opposed to such movements as romanticism or surrealism, in which subjects may receive highly symbolic or idealistic treatment.')
# ('moral_authority.noun.0', 'The quality or characteristic of being respected for having good character or knowledge, especially as a source of guidance or an exemplar of proper conduct.')
# None
# ('fifth_wall.noun.2', 'Any of various other divisions between groups of people in the theatre.')
# ('patmosian.noun.1', "A believer in Saint John's apocalyptic vision.")
# ('coryphaeus.noun.0', 'The conductor or leader of the chorus of a drama., synonyms :coryphée')
# ('mean.noun.0', 'A method or course of action used to achieve some result. (from 14th c.)')
# ("light_of_one's_eye.noun.0", "One's beloved.")
# ('preface.noun.0', 'The beginning or introductory portion that comes before the main text of a document or book., synonyms :forespeech, foretalk, foreword, introduction, proem, prologue')
# ('sketch.noun.1', 'A rough design, plan, or draft, as a rough draft of a book.')
# ('rinky-dink.noun.0', 'An amateur or someone who is underqualified.')
# ('eggcrate.noun.5', 'Grid-like support structure.')
# ('nutso.noun.0', 'Crazy person; crackpot or lunatic.')
# ('loo.noun.7', 'A lavatory: a room used for urination and defecation.')
# ('delicate.noun.0', 'A delicate item of clothing, especially underwear or lingerie.')
# ('none.noun.0', 'A person without religious affiliation.')
# ('snare.noun.0', 'A trap (especially one made from a loop of wire, string, or leather).')
# ('sociation.noun.1', 'The stable interactions and influences among the species within a coenose.')
# ('odd_job.noun.1', 'Task of an incidental, unspecialized nature.')
# ('venire.noun.0', 'A writ of venire facias.')
# None
# ('pursiness.noun.3', 'The state of being puckered.')
# ('post.noun.9', 'A station, or one of a series of stations, established for the refreshment and accommodation of travellers on some recognized route.')
# ('nature.noun.1', 'The innate characteristics of a thing. What something will tend by its own constitution, to be or do. Distinct from what might be expected or intended.')
# ('wyrd.noun.0', 'Fate, destiny, particularly in an Anglo-Saxon or Old Norse context.')
# ('coatful.noun.2', 'A quantity that sits on a coat.')
# ('swoose.noun.1', 'A person or thing sharing the characteristics of two otherwise separate groups; a hybrid (also see Swoose)')
# ('pull_time.noun.2', 'The time when trucks pull in for loading and pull out with new loads.')
# ('foo.noun.2', 'A mock deity of early science fiction fandom; a fannish ghod.')
# ('inverted_circumflex.noun.1', 'Any (diacritic) obtained by (rotating) a circumflex ((ˆ)) 180(°).')
# ('castellany.noun.1', 'The jurisdiction of a castellan, the district controled by a castle.')
# ('arctic_bear.noun.2', 'Any bear that lives in the Arctic.')
# ('mercenary.noun.0', 'One motivated by gain, especially monetary.')
# ('incivility.noun.0', 'The state of being uncivil; lack of courtesy; rudeness in manner., synonyms :impoliteness')
# ('green_belt.noun.2', 'Someone who has earned the rank of green belt.')
# ('earl.noun.2', '(from=English) from the English noun earl.')
# ('hand.noun.15', '"That which is, or may be, held in a hand at once."')
# None
# ('appearance.noun.2', 'The way something looks; personal presence, synonyms :aspect, mien')
# ('knightdom.noun.2', 'The sphere or world of knights; knights collectively')
# ('discord.noun.1', 'Tension or strife resulting from a lack of agreement; dissension.')
# ('turn_of_foot.noun.0', '(horse racing) The ability to accelerate quickly.')
# ('part.noun.14', 'Each of two contrasting sides of an argument, debate etc.; "hand".')
# ('sundowner.noun.1', 'An itinerant worker, a swagman.')
# ('grievance.noun.2', 'Feelings of being wronged; outrage.')
# ('ditto.noun.2', 'A copy; an imitation.')
# None
# ('attack.noun.0', 'An attempt to cause damage, injury to, or death of opponent or enemy.')
# ('carol.noun.3', '(from=Germanic languages), popular in the middle of the 20th century.')
# ('initialer.noun.0', 'The artist who decorates the initial letters in an illuminated manuscript.')
# ('dodo.noun.0', 'A large, flightless bird, †"Raphus cucullatus", related to the pigeon, that is now extinct (since the 1600s) and was native to Mauritius.')
# ('planetoid.noun.2', 'A larger, planetary, body in orbit around the Sun, such as Vesta or (candidate) dwarf planets such Eris or Sedna')
# ("rat's_nest.noun.0", 'Something that is excessively complicated, entangled, or disorderly.')
# ('case.noun.0', 'An actual event, situation, or fact.')
# ('tabbyhood.noun.0', 'The state of being an adult female cat.')
# ('tact.noun.2', 'Sensitive mental touch; special skill or faculty; keen perception or discernment; ready power of appreciating and doing what is required by circumstances; the ability to say the right thing. (from early 19th c.), synonyms :sensitivity, consideration, diplomacy, tactfulness')
# ('ologun.noun.1', 'A Yoruba warrior chief.')
# ('break.verb.36', 'To demulsify.')
# ('angle-shoot.verb.0', 'To fire or shoot from an angle.')
# ('touch.verb.19', 'To deal with in speech or writing; briefly to speak or write ("on" or "upon" something). (from 14th c.)')
# ('make_love.verb.0', 'To make amorous approaches (to); to woo, romance, court. (from 16th c.)')
# ('afterthink.verb.0', 'To think about after the fact, reflect on.')
# ('bewit.verb.0', 'To bequeath.')
# None
# ('revirginate.verb.1', 'To restore to virginity; to make into a virgin again.')
# ('respot.verb.2', 'To move a commercial or military vehicle or vehicles into a new position in order to make room for other activity or to allow the moved vehicles to be worked on.')
# None
# ('underwrap.verb.4', 'To wrap such that the wrapping does not go all the way to the edge.')
# ('stitch_up.verb.1', 'To maliciously or dishonestly incriminate someone; to set up (in the sense trap or ensnare)')
# ('depart.verb.5', 'To go away from; to leave.')
# ('concentre.verb.2', 'To bring together at a common centre.')
# ('uncowl.verb.2', "To remove or pull back one's cowl.")
# ('hollow.verb.0', 'to make a hole in something; to excavate')
# ('run.verb.52', 'To have growth or development.')
# ('overplate.verb.2', 'To form an overly thick plate on top of something.')
# None
# ('object.verb.2', 'To set before or against; to bring into opposition; to oppose.')
# ('run_after.verb.4', 'To seek to participate in, devote oneself to (something).')
# ('denumber.verb.1', 'To go from a number to the item or element that it indexes.')
# ('impearl.verb.0', 'To form into pearls, or make pearly.')
# ('stickle.verb.2', 'To raise objections; to argue stubbornly, especially over minor or trivial matters.')
# ('overween.verb.0', 'To think too highly or arrogantly of (oneself).')
# ('undertake.verb.3', 'To pledge; to assert, assure; to dare say.')
# ('will.verb.7', 'To wish, desire. (9th–19th c.)')
# ('elongate.verb.0', 'To make long or longer by pulling and stretching; to make elongated., synonyms :extend, stretch')
# ('mistify.verb.1', 'To turn into mist')
# ('stay.verb.16', 'To remain in a particular place, especially for a definite or short period of time; sojourn; abide.')
# ('spew.verb.0', 'To eject forcibly and in a stream')
# ('twerk.verb.1', 'To move the body in a sexually suggestive twisting or gyrating fashion.')
# ('marble.verb.0', 'To cause (something to have) the streaked or swirled appearance of certain types of marble, for example by mixing viscous ingredients incompletely, or by applying paint or other colorants unevenly., synonyms :marbleize')
# ('jackhammer.verb.6', 'To strike (something) repeatedly with force, to pound.')
# ('chirk.verb.0', 'To become happier.')
# ('upbraid.verb.3', 'To object or urge as a matter of reproach; to cast up; – with "to" before the person.')
# ('enlarge.verb.2', 'To increase the capacity of; to expand; to give free scope or greater scope to; also, to dilate, as with joy, affection, etc.')
# ('therapy.verb.1', 'To undergo a therapy.')
# ('wither.verb.1', 'To cause to shrivel or dry up.')
# ('roil.verb.0', 'To render turbid (to agitate) by stirring up the dregs or sediment of')
# ('bowk.verb.0', 'To belch, to burp.')
# ('fill.verb.1', 'To add contents to (a container, cavity(,) or the like) so that it is full.')
# ('stallionize.verb.1', 'To make virile and manly.')
# None
# ('wheel.verb.2', 'To change direction quickly, turn, pivot, whirl, wheel around.')
# ('twine.verb.2', 'To wind about; to embrace; to entwine.')
# ('twitch.verb.1', 'To jerk sharply and briefly.')
# None
# ('suck_all_the_air_out_of.verb.0', 'To dominate or overwhelm.')
# None
# ('joy.verb.0', 'To feel joy, to rejoice.')
# ('politically_correct.verb.0', 'To modify in a way that is more respectful to minorities.')
# ('come_together.verb.1', 'To harmonize socially; to come to an amicable agreement; to ally or band together.')
# ('try.verb.20', 'To strain; to subject to excessive tests.')
# ('fettle.verb.0', 'To sort out, to fix, to mend, to repair.')
# ('wraggle.verb.0', 'To wag about with a wiggling motion.')
# ('want.verb.7', 'To be lacking or deficient or absent. (from 13th c.)')
# ('object.verb.2', 'To set before or against; to bring into opposition; to oppose.')
# ('play.verb.18', 'To bring into sportive or wanton action; to exhibit in action; to execute.')
# ("don't.verb.0", 'do not (negative auxiliary<ref>Arnold M. Zwicky and Geoffrey K. Pullum, [http://www.stanford.edu/~zwicky/ZPCliticsInfl.pdf "Cliticization vs. Inflection: English "n\'t], "Language" \'\'\'59\'\'\' (3), 1983, pp. 502-513</ref>)')
# ('attain.verb.0', 'To gain (an object or desired result)., synonyms :accomplish, achieve, get')
# ('go_nuclear.verb.3', 'To throw a fit; To become enraged with an angry outburst.')
# ('wish.verb.4', 'To request or desire to do an activity.')
# ('let_loose.verb.1', 'or (on) To shout, make a loud sound, or perform a sudden, vehement action; to behave in a raucous, frenzied manner.')
# ('tire.verb.6', 'To seize, rend, or tear something as prey; to be fixed upon, or engaged with, anything.')
# ('floof.verb.0', 'To make something fluffy, to fluff (up).')
# ('octavate.verb.1', 'To (resonate) or sound one octave higher or lower.')
# ('shore.verb.2', 'To reinforce (something at risk of failure).')
# ('unstring.verb.3', 'To remove from a string; to release something that has been strung up or strung together.')
# ('grave.verb.6', 'To write or delineate on hard substances, by means of incised lines; to practice engraving.')
# ('stay.verb.2', 'To stop; detain; keep back; delay; hinder.')
# ('arrest.verb.0', 'To stop the motion of (a person or animal). (14th-19th c.)')
# None
# ('puddle-jump.verb.3', 'To move a small distance; to go from one small thing to another.')
# ('sciencey.adjective.0', 'Scientific; of or pertaining to science.')
# ('underwrapped.adjective.4', 'Having an end that protrudes underneath.')
# ('blond.adjective.1', 'Having blond hair.')
# ('distanceless.adjective.0', 'Without distance.')
# ('strange.adjective.0', 'Not normal; odd, unusual, surprising, out of the ordinary.')
# ('speculative.adjective.0', 'Characterized by speculation; based on guessing, unfounded opinions, or extrapolation.')
# ('connected.adjective.0', '"(usually with "well-"):" Having favorable rapport with a powerful entity.')
# ('placable.adjective.0', 'Able to be easily pacified; quick to forgive.')
# None
# ('odd.adjective.11', 'Out of the way, secluded.')
# ('current.adjective.0', 'existing or occurring at the moment, synonyms :present')
# ('hackerish.adjective.0', 'Resembling or characteristic of a hacker (technically skilled computer enthusiast).')
# ('happening.adjective.1', 'Trendy, up-to-the-minute.')
# ('punctilious.adjective.0', 'Strictly attentive to detail; meticulous or fastidious, particularly to codes or conventions.')
# ('male.adjective.1', 'Characteristic of this sex/gender. (masculine), (manly).')
# None
# ('computative.adjective.1', 'calculating, shrewdly or selfishly reckoning')
# ('bolt-on.adjective.1', 'Used to extend an existing system, operating as an add-on or plug-in.')
# ('underwrapped.adjective.4', 'Having an end that protrudes underneath.')
# ('gameful.adjective.3', 'Pertaining to games.')
# ('underhanded.adjective.3', 'Secret; surreptitious.')
# ('incessive.adjective.2', 'Continual or successive; unceasing.')
# None
# ('fatty.adjective.2', 'Literally or figuratively large.')
# ('schooly.adjective.0', 'Of or relating to school.')
# ('gluttonous.adjective.0', 'Given to excessive eating; prone to overeating.')
# ('sappy.adjective.3', 'Spongy; Having spaces in which large quantities of sap can flow.')
# ('gutted.adjective.3', 'Deeply disappointed; annoyed; down.')
# ('saturnic.adjective.3', 'Saturnalian: riotously merry; dissolute')
# ('tight.adjective.0', 'Firmly held together; compact; not loose or open.')
# ('initiatory.adjective.1', 'inceptive, initial, inaugural or introductory')
# ('mercurial.adjective.5', 'Pertaining to Mercury, the Roman god of, among other things, commerce, financial gain, communication, and thieves and trickery; hence , money-making; crafty. (from 15th c.)')
# ('peevish.adjective.0', 'Characterized by or exhibiting petty bad temper, bad-tempered, moody, cross. (from 1520)')
# ('pachydermic.adjective.5', 'Thick-skinned; insensitive.')
# ('happy.adjective.2', 'Content, satisfied (with or to do something); having no objection (to something).')
# ('fleshly.adjective.3', 'Of or relating to non-spiritual or non-religious matters., synonyms :secular, worldly')
# ('unwearied.adjective.1', 'Never tiring; tireless., synonyms :indefatigable, inexhaustible, unflagging, untiring, unwearying')
# ('instant.adjective.2', 'Occurring immediately; immediate; present., synonyms :instantaneous')
# ('voluble.adjective.1', 'Expressed readily or at length and in a fluent manner.')
# ('warm.adjective.1', 'Caring and friendly, of relations to another person.')
# ('tender-handed.adjective.1', 'With hands that are very sensitive and easily hurt.')
# ('killer.adjective.1', 'Causing death, destruction, or obliteration.')
# ('shy.adjective.2', 'Cautious; wary; suspicious.')
# ('close.adjective.3', 'Intimate; well-loved.')
# ('backwood.adjective.1', 'Rustic, unsophisticated, countrified.')
# ('grouty.adjective.0', 'Full of grout(s), that is, sediment.')
# ('bland.adjective.3', 'Mild; soft, gentle, balmy; smooth in manner; suave.')
# ('close.adjective.9', 'Out of the way of observation; secluded; secret; hidden.')
# ('bitter.adjective.3', 'Cynical and resentful.')
# ('downstrike.adjective.5', 'To go in a downward direction.')
# ('accursed.adjective.1', 'Doomed to destruction or misery; cursed; anathematized.')
# ('prebendal.adjective.2', 'Of or pertaining to an honorary religious title granted by the state.')
# ('sequacious.adjective.0', 'Prone to following or yielding to physical pressure; easily shaped or molded.')
# ('absolute.adjective.9', 'Independent of arbitrary units of measurement, standards, or properties; not comparative or relative.')
# ('mighty.adjective.3', 'Accomplished by might; hence, extraordinary; wonderful.')
# ('diverse.adjective.0', 'Consisting of many different elements; various.')
# ('underhanded.adjective.2', 'Insincere; sarcastic.')
# ('zoomy.adjective.0', 'That goes "zoom!"')
# ('ambitious.adjective.2', 'Resulting from, characterized by, or indicating, ambition')
# ('fatty.adjective.0', 'Containing, composed of, or consisting of fat.')
# ('profligate.adjective.0', 'Inclined to waste resources or behave extravagantly.')
# ('nice.adjective.0', 'Pleasant, satisfactory. (from 18th c.)')
# ('main.adjective.5', 'Great in size or degree; important, powerful, strong, vast.')
# ('superdominant.adjective.1', 'Having a disproportionate degree of influence or salience.')
# ('zombic.adjective.1', 'resembling a zombie')
# ('microformal.adjective.1', 'Pertaining to the characteristics and patterns of lines or phrases, as opposed to the structure of the entire work.')
# ('plutonian.adjective.1', 'Of, relating to, or having characteristics associated with the underworld; dark, gloomy; mournful., synonyms :plutonic')
# ('mannish.adjective.1', 'Resembling or characteristic of a grown man (as opposed to a boy); mature, adult. (from 16th c.), synonyms :manly, grown up')
# ('plain.adjective.11', 'Honest and without deception; candid, open; blunt. (from 14th c.)')
# ('disparate.adjective.0', 'Composed of inherently different or distinct elements; incongruous.')
# ('antique.adjective.1', 'Belonging to former times, not modern, out of date, old-fashioned.')
# ('recognitory.adjective.2', 'Pertaining to recognizing (acknowledging the existence, status or validity of something).')
# ('demonifugic.adjective.1', 'Having, or believed to have, magical power to dispel or protect against demons.')
# ('incontinently.adverb.0', 'In an incontinent manner; without restraint, or without due restraint.')
# ('about.adverb.11', 'Going to; on the verge of; intending to. (First attested in the early 16th century.<ref name=SOED/>)')
# ('scarcely.adverb.0', 'Probably not.')
# ('slack-handed.adverb.1', 'Idly or carelessly.')
# ('betimes.adverb.0', 'In good season or time; early, especially in the morning; seasonably.')
# ('back.adverb.1', 'Away from the front or from an edge.')
# ('all.adverb.0', 'Entirely.')
# ('affectedly.adverb.0', 'In an affected manner; hypocritically; with more show than reality.')
# ('light-handed.adverb.0', 'Carrying very little.')
# ('scarcely.adverb.0', 'Probably not.')
# ('templatically.adverb.1', 'In a manner that conforms to a template.')
# ('fairly.adverb.0', 'In a fair manner; not biased or skewed or favouring a certain party, synonyms :justly, frankly')
# 441477

# %% [markdown]
# 74 instances are corrected using the iterative binary classification
