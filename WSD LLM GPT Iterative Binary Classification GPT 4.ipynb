# %% [markdown]
# # This phase Try to evaluate the WSD as iterative Binary Classification.

# %% [markdown]
# - Steps to follow
#
# 1. Identify the senses/glosses based on the POS tag
# 2. Iterative idenitify the sense/gloss based on the approach

# %%
import os, yaml, re
from openai import OpenAI, ChatCompletion

# %%
with open('cadentials.yaml') as f:
    cadentials = yaml.load(f, Loader=yaml.FullLoader)

os.environ['OPENAI_API_KEY'] = cadentials['OPENAI_API_KEY']

# %%
client = OpenAI()

# %%
def complete_model(USER_MESSAGE):
    response = client.chat.completions.create(
                                            model = 'gpt-4-0125-preview',
                                            messages = [
                                                        {"role": "system", "content" : "You are a helpful assitant to identify the tag for sense of a word"},
                                                        {"role": "user", "content": USER_MESSAGE}              
                                                        ],
                                            temperature=0,
                                            max_tokens=1500
                                            )
    return str(response.choices[0].message.content)

# %%
# Read data from file
with open('senses.txt', 'r',encoding="utf8") as file:
    data = file.read()

# Split the data into entries based on empty lines
entries = data.strip().split('\n\n')
print("No of sense tags in FEWS dataset ",len(entries))

# Create a list of lists for each entry's details
list_of_lists = []
for entry in entries:
    details = entry.split('\n')
    entry_list = []
    for detail in details:
        _, value = detail.split(':', 1)
        entry_list.append(value.strip())
    list_of_lists.append(entry_list)

# Print the instance from the sense tag
print(list_of_lists[0])
# Out:
# No of sense tags in FEWS dataset  663730
# ['dictionary.noun.0', 'dictionary', "A reference work with a list of words from one or more languages, normally ordered alphabetically, explaining each word's meaning, and sometimes containing information on its etymology, pronunciation, usage, translations, and other data.", '', '1', 'wordbook']

# %%
#converting the word into the base word as the sense are kept in base
def word_base(word):
    try:
        word=stemmer.stem(word)
        base_word = lemmatizer.lemmatize(word)
        return base_word
    except:
        return word

# %%
#function to retrieve the word meaning from the list_of_list list
#this function will specifically read the sense id and the meaning(gloss) which is required for the processing.
def retrieve_meanings(word, data):
    meanings_dict = {}
    for entry in data:
        if word == entry[0].split(".")[0]:
            if entry[-1] !="":
                meanings_dict[entry[0]] = entry[2]+", synonyms :"+entry[-1]
            else:
                meanings_dict[entry[0]] = entry[2]
    return meanings_dict

# %%
#Extract the sentence without <wsd> token and the index
def extract_word_and_index(sentence):
    # Find the start and end index of the <WSD> tags
    start_index = sentence.find('<WSD>')    
    end_index = sentence.find('</WSD>')
    

    if start_index != -1 and end_index != -1:
        # Extract the word between <WSD> tags
        word = sentence[start_index + len('<WSD>'):end_index]

        # Remove <WSD> and </WSD> tags from the sentence
        cleaned_sentence = sentence[:start_index] + word+" " + sentence[end_index + len('</WSD>'):]
            
        return cleaned_sentence.strip()

# %%
#Function to identify the WSD word from the given sentence and return the WSD word on a sentence
def wsdword(text):
    match = re.search(r'<WSD>(.*?)</WSD>', text)
    if match:
        word_inside_wsd = match.group(1)
        return word_inside_wsd

# %%
#Funtion to counts the number of tokens : input and output tokens
from nltk.tokenize import word_tokenize

def count_tokens(text):
    # Tokenize the input text
    tokens = word_tokenize(text)
    
    # Count the tokens in the input
    token_count = len(tokens)
    
    return token_count

# %%
#Word lemmatizer to get the base word of the WSD word
import nltk
from nltk.stem import WordNetLemmatizer, PorterStemmer

nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\2358452\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import json
def load_dictionary_from_file(filename):
    try:
        with open(filename, 'r') as file:
            data_dict = json.load(file)
        return data_dict
    except FileNotFoundError:
        # Handle the case where the file doesn't exist
        return None
    except json.JSONDecodeError:
        # Handle the case where the file contains invalid JSON
        return None

# %%
def postag_preprocess(pos_tag):
    if pos_tag=="adj":
        return "adjective"
    elif pos_tag=="noun" or pos_tag=="verb":
        return pos_tag
    else:
        return None

# %%
loaded_dict = load_dictionary_from_file("my_dictionary.json")

# %%
def sense_Tag_Return_pipeline(sentence,postag,wordwsd):
    try:
        ob="{"
        cb="}"
        
        meanings = retrieve_meanings(wordwsd, list_of_lists)
        #print(meanings)
        cleaned_sentence= extract_word_and_index(sentence) 
        
        #retrieving the data form the dictionary
        filtered_definitions = {key: value for key, value in meanings.items() if postag in key}
        meaning_list= list(filtered_definitions.items())      
        #print(meaning_list)
        count=0 #variable to count the tokens 
        
        if wsdword(sentence) in loaded_dict:
            #print("examples found")
            examples=loaded_dict[wsdword(sentence)]
            try:
                examples=examples[postag]
            except:
                examples=examples
            

        elif word_base(wsdword(sentence)) in loaded_dict:
            #print("examples found")
            examples=loaded_dict[word_base(wsdword(sentence))]
            try:
                examples=examples[postag]
            except:
                examples=examples
        else:
            examples=None
            
        #print(examples)
        
        output=meaning_list[0]
        count=0 #variable to count the tokens 
        for count_meaning in range(0,len(meaning_list)-1):
            #print("new Iteration")    
            sense_def1=[]
            sense_def2=[]
            
            for example in examples:
                if output[0] in example:
                    sense_def1.append(example)
                elif meaning_list[count_meaning+1][0] in example:
                    sense_def2.append(example)

            #print("Sense Examples")  
            #print(sense_def1)
            #print(sense_def2)

                    
            prompt = f'''You are going to identify the most suitable sense tag of an ambiguous word in English sentence.
    1. Below are two possible meanings for word {wordwsd}. Comprehend the sense tags and meanings.
        - 1st meaning {output}
        - 2nd meaning {meaning_list[count_meaning+1]}
    2. You can learn more on the usage of each word and the its sense through the examples below if provided. 
        - 1st meaning Examples : {sense_def1}
        - 2nd meaning Examples : {sense_def2}
    3. Now carefully examine the sentence below. The ambiguous word is enclosed within <WSD>."{sentence}"
    4. Analyze the sentence carefully and identify the meaning of the ambiguous word. Use below techniques
    - Traverse the sentence and identify the important keywords which help to identify the meaning of the ambiguous word. 
    - Then you can think about the contextual meaning of the sentence and decide the most suitable meaning for the ambiguous word.
    5. Based on the identified meaning, try to find the most appropriate senseID from the above two sense ids. Selection of a one sense is mandatory. 
    6. Return only the identified senseid in the below JSON format.
    {ob}"sense_id":  the identified sense id{cb}  ''' 
            
            count+=count_tokens(prompt)
            response=complete_model(prompt)
            #print("Response :")
            #print(response)
            count+=count_tokens(str(output))
            if output[0] in response:
                output=output
            else:
                output=meaning_list[count_meaning+1]

            #print("Output of each iteration:")
            #print(output)


        return output,count
    
    except:
        return None,0

# %%
import datetime
#evaluating the results
filename="missing_data_analysis_4/binaryclassification"+datetime.date.today().strftime("%B %d, %Y")+".txt"
file=open("missing_data_analysis_4/missing_test_data.txt","r",encoding="utf8")

file2=open(filename,"w",encoding="utf8")
totalTokens=0
for i in file:
    lst=i.split("	")
    sentence,senseid=lst[0],lst[1]
    postag=senseid.split(".")[1]  #postag 
    wordfromtext=senseid.split(".")[0] #wsdword
    #print(postag)
    foutput,token_count=sense_Tag_Return_pipeline(sentence,postag,wordfromtext)
    totalTokens+=token_count
    #print(output)
    print(foutput)
    #writing the output in the file
    file2.write(str(foutput) + "\n")
    

file.close()
file2.close()
print(totalTokens)
# Out:
# ('beast.noun.0', 'Any animal other than a human; usually only applied to land vertebrates, especially large or dangerous four-footed ones.')
# ('brake.noun.1', 'A thicket, or an area overgrown with briers etc. (from 15th c.)')
# ('acquirement.noun.1', 'The act or fact of acquiring something; acquisition. (from 17th c.)')
# ('stage.noun.1', 'A platform; a surface, generally elevated, upon which show performances or other public events are given.')
# ('part.noun.1', 'A fraction of a whole. (t)')
# ('red_shirt.noun.0', "A member of the UDD (National United Front for Democracy), supporters of Prime Minister  Shinawatra, (and subsequently Abhisit Vejajiva) in the conflict in Thailand after the 2006 coup d'etat.")
# ('people_pod.noun.4', 'A small chamber for a single person.')
# ('entropology.noun.0', 'The study of human actions that lead to the disintegration and increasing disorder of highly evolved social systems.')
# ('corruption.noun.8', '(en) Something originally good or pure that has turned evil or impure; a perversion.')
# ('palaver.noun.3', 'Fuss.')
# ('interest.noun.3', 'An involvement, claim, right, share, stake in or link with a financial, business, or other undertaking or endeavor.')
# ('concretization.noun.1', 'Something specific which is the result of a process of concretizing a general principle or idea.')
# ('bourne.noun.1', 'A goal or destination.')
# ('bizarreness.noun.1', 'The result or product of being bizarre.')
# ('fafiation.noun.1', 'The state or result of having fafiated; having exited fandom due to other obligations.')
# ('farming.noun.1', 'A farming operation; a farm, or instance of farming on a piece of land.')
# ('pique.noun.0', 'A feeling of enmity; ill-feeling, animosity; a transient feeling of wounded pride.')
# ('naturalism.noun.0', 'A state of nature; conformity to nature.')
# ('pigstick.noun.3', 'A stick that is used for stabbing.')
# None
# ('stream.noun.3', 'All moving waters.')
# ('patmosian.noun.1', "A believer in Saint John's apocalyptic vision.")
# ('mean.noun.0', 'A method or course of action used to achieve some result. (from 14th c.)')
# ('supercunt.noun.1', 'An exceptionally annoying person.')
# ('sketch.noun.1', 'A rough design, plan, or draft, as a rough draft of a book.')
# ('loo.noun.7', 'A lavatory: a room used for urination and defecation.')
# ('none.noun.0', 'A person without religious affiliation.')
# ('odd_job.noun.1', 'Task of an incidental, unspecialized nature.')
# ('disciplinist.noun.1', 'A disciplinarian; one who stresses obedience to authority.')
# ('itchy_trigger_finger.noun.1', 'The metaphorical trigger finger of a person with a tendency or readiness to act in haste or without consideration; a tendency to so act.')
# ('wight.noun.2', 'A ghost, deity or other supernatural entity.')
# ('nature.noun.1', 'The innate characteristics of a thing. What something will tend by its own constitution, to be or do. Distinct from what might be expected or intended.')
# ('wyrd.noun.0', 'Fate, destiny, particularly in an Anglo-Saxon or Old Norse context.')
# ('langlauf.noun.1', 'A langlauf run; a trip cross-country skiing.')
# ('pull_time.noun.2', 'The time when trucks pull in for loading and pull out with new loads.')
# ('wet_sanding.noun.1', 'The process of smoothing damp material with a sponge.')
# ('castellany.noun.1', 'The jurisdiction of a castellan, the district controled by a castle.')
# ('people_pod.noun.1', 'A bus-like compartment carried by a lift truck, proposed in the late 1950s for transporting people and luggage from the airport terminal to an aircraft.')
# ('matron.noun.1', 'A wife or a widow, especially, one who has borne children.')
# ('incivility.noun.1', 'Any act of rudeness or ill-breeding.')
# ('arrival.noun.0', 'The act of arriving or something that has arrived.')
# ('hand.noun.25', 'Actual performance; deed; act; workmanship; agency; hence, manner of performance.')
# None
# None
# ('knightdom.noun.1', 'The quality, or condition of a knight; knighthood')
# ('turn_of_foot.noun.2', '(by extension) A burst of speed.')
# ('vanishing_point.noun.1', 'The situation in which, place where, or point in time when some object or phenomenon is no longer observable or notable.')
# ('ditto.noun.2', 'A copy; an imitation.')
# ('subvention.noun.0', 'A subsidy; provision of financial or other support.')
# ('needle_dick.noun.0', 'A tiny penis')
# ('rapefic.noun.1', 'Such fan fiction collectively.')
# ('attack.noun.2', 'A time in which one attacks; the offence of a battle.')
# ('witness.noun.4', 'Something that serves as evidence; a sign or token.')
# ('case.noun.4', '(law) A legal proceeding, lawsuit.')
# ('dope_sheet.noun.0', 'A summary, ordinarily in the form of a document, containing important facts and background information concerning a person, activity, or other subject matter.')
# ('ologun.noun.1', 'A Yoruba warrior chief.')
# ('economicide.noun.1', "Genocide that results from destroying a people's economic basis.")
# ('zephyr.verb.0', 'To blow or move like a zephyr, or light breeze.')
# ('touch.verb.34', 'To influence by impulse; to impel forcibly.')
# ('afterthink.verb.0', 'To think about after the fact, reflect on.')
# ('kiss.verb.2', "Of two or more people, to touch each other's lips together, usually to express love or affection or passion.")
# ('adventure.verb.2', 'To try the chance; to take the risk.')
# ('muffle.verb.4', 'To prevent seeing, or hearing, or speaking, by wraps bound about the head; to blindfold; to deafen.')
# ('dismay.verb.2', 'To take dismay or fright; to be filled with dismay.')
# ('revirginate.verb.3', 'To restore to a pristine state; to rejuvinate.')
# ('thrill.verb.1', 'To (cause something to) tremble or quiver.')
# None
# ('tighten_up.verb.4', 'To become focused and serious; To stop any vacillation or inconsistency.')
# None
# ('underwrap.verb.1', 'To provide with a wrapping that will subsequently be covered or wrapped by something else.')
# ('concentre.verb.2', 'To bring together at a common centre.')
# ('uncowl.verb.2', "To remove or pull back one's cowl.")
# ('applaud.verb.0', 'To express approval (of something) by clapping the hands.')
# None
# ('run.verb.52', 'To have growth or development.')
# ('overamplify.verb.1', 'To amplify to an extent that is undesirably loud.')
# ('overplate.verb.2', 'To form an overly thick plate on top of something.')
# ('disembogue.verb.0', 'To come out into the open sea from a river etc.')
# ('object.verb.0', 'To disagree with something or someone; especially in a Court of Law, to raise an objection.')
# ('address.verb.7', 'To direct, as words, to (anyone or anything); to make, as a speech, petition, etc. to (any audience).')
# ('rankle.verb.1', 'To fester.')
# ('mop_up.verb.6', 'To get rid of enemies at a certain area.')
# ('run_after.verb.4', 'To seek to participate in, devote oneself to (something).')
# ('denumber.verb.3', 'To remove from a numbered list of official items, members, etc.')
# ('stickle.verb.5', 'To separate combatants by intervening.')
# ('overween.verb.1', 'To make or render arrogant and overweening.')
# ('will.verb.9', "To try to make (something) happen by using one's will (intention). (from 10th c.)")
# ('stay.verb.16', 'To remain in a particular place, especially for a definite or short period of time; sojourn; abide.')
# ('jackhammer.verb.6', 'To strike (something) repeatedly with force, to pound.')
# None
# ('wither.verb.1', 'To cause to shrivel or dry up.')
# ('zephyr.verb.0', 'To blow or move like a zephyr, or light breeze.')
# ('fill.verb.3', 'To become full.')
# ('close_the_book_on.verb.1', 'To finish; to bring to an end.')
# ('wheel.verb.2', 'To change direction quickly, turn, pivot, whirl, wheel around.')
# None
# ('twine.verb.2', 'To wind about; to embrace; to entwine.')
# None
# ('suck_all_the_air_out_of.verb.0', 'To dominate or overwhelm.')
# ('joy.verb.2', 'To give joy to; to congratulate.')
# ('recover.verb.7', "To regain one's composure, balance etc.")
# ('overset.verb.5', 'To unbalance (a situation, state etc.); to confuse, to put into disarray.')
# ('come_together.verb.1', 'To harmonize socially; to come to an amicable agreement; to ally or band together.')
# ('apprehend.verb.3', 'To anticipate; especially, to anticipate with anxiety, dread, or fear; to fear.')
# None
# ('try.verb.20', 'To strain; to subject to excessive tests.')
# ('conduct.verb.3', 'To serve as a medium for conveying; to transmit (heat, light, electricity, etc.)')
# ('fettle.verb.1', 'To make preparations; to put things in order; to do trifling business.')
# ('wraggle.verb.2', 'To pester.')
# ('bristle.verb.1', 'To appear as if covered with bristles; to have standing, thick and erect, like bristles.')
# ('go_nuclear.verb.3', 'To throw a fit; To become enraged with an angry outburst.')
# ('jackhammer.verb.3', 'To move like a jackhammer.')
# ('kick.verb.1', 'To make a sharp jerking movement of the leg, as to strike something.')
# ('wish.verb.5', 'To recommend; to seek confidence or favour on behalf of.')
# ('undercode.verb.0', "To communicate using codes that do not convey the entire message, but which rely on the recipient's construction of meaning through connotation or subtexts.")
# None
# ('let_loose.verb.1', 'or (on) To shout, make a loud sound, or perform a sudden, vehement action; to behave in a raucous, frenzied manner.')
# ('octavate.verb.1', 'To (resonate) or sound one octave higher or lower.')
# ('trip.verb.0', "to fall over or stumble over an object as a result of striking it with one's foot")
# None
# ('shore.verb.2', 'To reinforce (something at risk of failure).')
# ('unstring.verb.2', 'To defuse or relax.')
# ('bename.verb.1', 'To name; give a name (to); mention by name; nominate; denominate; call.')
# ('stay.verb.3', 'To restrain; withhold; check; stop.')
# ('drape.verb.1', 'To spread over, cover.')
# ('peach.verb.1', 'To (inform) against.')
# ('sciencey.adjective.1', 'Apparently, but not necessarily, scientific; having the trappings of science., synonyms :sciencelike')
# ('light-handed.adjective.5', 'Not having a full complement of workers.')
# ('underwrapped.adjective.3', 'Having an inner wrapping.')
# ('speculative.adjective.2', 'Pertaining to financial speculation; Involving or resulting from high-risk investments or trade.')
# ('placable.adjective.0', 'Able to be easily pacified; quick to forgive.')
# ('unpretended.adjective.2', 'Without complication or embellishment; straightforward; simple and direct.')
# ('funky.adjective.2', 'Cool; great; excellent.')
# ('lunar.adjective.4', 'Of or pertaining to travel through space between the Earth and the Moon, or exploration and scientific investigation of the Moon.')
# ('numb-handed.adjective.1', 'Inept or clumsy.')
# ('hackerish.adjective.0', 'Resembling or characteristic of a hacker (technically skilled computer enthusiast).')
# ('punctilious.adjective.0', 'Strictly attentive to detail; meticulous or fastidious, particularly to codes or conventions.')
# None
# ('monsterful.adjective.0', 'Rare; extraordinary; marvelous')
# ('bolt-on.adjective.1', 'Used to extend an existing system, operating as an add-on or plug-in.')
# ('memoriter.adjective.0', 'That is or has been recited from memory; that has been learned by heart.')
# ('drooly.adjective.1', 'Covered in drool.')
# ('troublous.adjective.2', 'Causing trouble; troublesome, vexatious.')
# ('incessive.adjective.2', 'Continual or successive; unceasing.')
# ('schooly.adjective.1', 'Studious, involving study.')
# ('chasmous.adjective.0', 'Like a chasm or gulf.')
# ('gluttonous.adjective.0', 'Given to excessive eating; prone to overeating.')
# ('lost_to_the_world.adjective.3', "Mentally focussed on one's own thoughts or feelings, or on some task, to such a degree that one is unaware of other people or of one's surroundings; unconscious.")
# ('off_the_grid.adjective.2', 'Isolated; in a remote location; in seclusion; not participating in some official process or system.')
# ('livid.adjective.1', 'Pale, pallid.')
# ('flatfooted.adjective.1', 'Blunt and unsubtle; lacking finesse.')
# ('unwearied.adjective.1', 'Never tiring; tireless., synonyms :indefatigable, inexhaustible, unflagging, untiring, unwearying')
# ('warm.adjective.7', 'Well off as to property, or in good circumstances; rich.')
# ('tender-handed.adjective.1', 'With hands that are very sensitive and easily hurt.')
# ('continent.adjective.2', 'Serving to restrain or limit; restraining; opposing.')
# ('killer.adjective.2', 'Distressing, uncomfortable.')
# ('dog_rough.adjective.1', 'Very difficult and unpleasant.')
# ('less.adjective.1', '(little): a smaller amount (of); not as much. (from 14th c.)')
# ('great.adjective.7', 'Arising\xa0from or\xa0possessing\xa0idealism; admirable; superior; commanding;\xa0heroic; illustrious;\xa0eminent.')
# ('sinister.adjective.1', 'Evil or seemingly evil; indicating lurking danger or harm.')
# ('close.adjective.17', 'Accurate; careful; precise; also, attentive; undeviating; strict.')
# ('bitter.adjective.3', 'Cynical and resentful.')
# ('unhusked.adjective.1', 'Having the husk on; still on the husk.')
# ('temperate.adjective.3', 'Living in an environment that is temperate, not extreme.')
# ('ambitious.adjective.2', 'Resulting from, characterized by, or indicating, ambition')
# ('fatty.adjective.1', 'Like fat; greasy.')
# ('profligate.adjective.0', 'Inclined to waste resources or behave extravagantly.')
# ('decent.adjective.0', 'Appropriate; suitable for the circumstances.')
# ('main.adjective.5', 'Great in size or degree; important, powerful, strong, vast.')
# ('superdominant.adjective.1', 'Having a disproportionate degree of influence or salience.')
# ('zombic.adjective.1', 'resembling a zombie')
# ('ithyphallic.adjective.3', 'Lascivious, obscene.')
# ('plutonian.adjective.1', 'Of, relating to, or having characteristics associated with the underworld; dark, gloomy; mournful., synonyms :plutonic')
# ('sere.adjective.0', 'Without moisture; dry., synonyms :sare, q1=Britain, archaic, sear')
# ('cultureful.adjective.1', 'Pertaining to intellectual activities.')
# ('achillean.adjective.2', 'Guided by emotional motives, especially rage, rather than reason.')
# ('disparate.adjective.1', 'Essentially different; of different species, unlike but not opposed in pairs; also, less properly, utterly unlike; incapable of being compared; having no common genus.')
# ('great.adjective.5', 'Extreme\xa0or more than\xa0usual.')
# ('cousinfucking.adjective.1', 'Motherfucking, goddamn.')
# ('demonifugic.adjective.1', 'Having, or believed to have, magical power to dispel or protect against demons.')
# ('about.adverb.10', 'In circuit; circularly; by a circuitous way; around the outside; in circumference. (First attested around 1350 to 1470.<ref name=SOED/>)')
# None
# ('scarcely.adverb.2', 'Almost not at all; by a small margin.')
# ('back.adverb.4', 'Earlier, ago.')
# ('seasonably.adverb.2', 'In a manner appropriate to the season.')
# ('together.adverb.0', 'At the same time, in the same place; in close association or proximity.')
# ('affectedly.adverb.0', 'In an affected manner; hypocritically; with more show than reality.')
# ('scarcely.adverb.2', 'Almost not at all; by a small margin.')
# ('youngly.adverb.0', 'While young; as a youth.')
# ('widely.adverb.0', 'commonly; generally; to a great degree')
# ('first_thing.adverb.1', 'Straight away, very soon.')
# 342013

# %% [markdown]
# - 57 instances are correctly identified
